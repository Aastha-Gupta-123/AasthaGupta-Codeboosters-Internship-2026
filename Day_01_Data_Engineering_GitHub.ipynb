# %%
import pandas

# %%
df=pandas.read_csv('/content/student_performance.csv')

# %%
df.head()
# Out:
#    student_id          name  age  gender        department  semester  \
# 0        1001  Aarav Sharma   19    Male  Computer Science         2
# 1        1002   Priya Patel   20  Female  Computer Science         2
# 2        1003   Rohit Verma   19    Male       Electronics         2
# 3        1004   Sneha Reddy   20  Female        Mechanical         2
# 4        1005    Arjun Nair   19    Male  Computer Science         2
#
#    math_score  science_score  english_score  programming_score  \
# 0          85             78             72                 91
# 1          76             82             88                 79
# 2          65             74             61                 55
# 3          70             80             75                 48
# 4          92             88             81                 95
#
#    attendance_percentage       city  admission_year
# 0                     92     Mumbai            2023
# 1                     87  Ahmedabad            2023
# ...

# %%
df.describe()
# Out:
#         student_id        age  semester  math_score  science_score  \
# count    30.000000  30.000000      30.0   30.000000      30.000000
# mean   1015.500000  19.733333       2.0   76.066667      77.833333
# std       8.803408   0.739680       0.0   11.467896       8.554423
# min    1001.000000  19.000000       2.0   56.000000      61.000000
# 25%    1008.250000  19.000000       2.0   67.250000      71.250000
# 50%    1015.500000  20.000000       2.0   75.500000      78.000000
# 75%    1022.750000  20.000000       2.0   85.750000      83.750000
# max    1030.000000  21.000000       2.0   95.000000      93.000000
#
#        english_score  programming_score  attendance_percentage  admission_year
# count      30.000000          30.000000              30.000000            30.0
# mean       74.166667          67.600000              84.500000          2023.0
# std        10.003735          21.041175               9.379913             0.0
# ...

# %%
df.shape
# Out:
# (30, 13)

# %%
df.columns
# Out:
# Index(['student_id', 'name', 'age', 'gender', 'department', 'semester',
#        'math_score', 'science_score', 'english_score', 'programming_score',
#        'attendance_percentage', 'city', 'admission_year'],
#       dtype='object')

# %%
df.tail()
# Out:
#     student_id            name  age  gender        department  semester  \
# 25        1026      Rekha Nair   20  Female       Electronics         2
# 26        1027   Gaurav Shukla   21    Male  Computer Science         2
# 27        1028   Sunita Pillai   19  Female             Civil         2
# 28        1029      Nitin Jain   20    Male        Mechanical         2
# 29        1030  Akanksha Yadav   19  Female  Computer Science         2
#
#     math_score  science_score  english_score  programming_score  \
# 25          72             77             73                 63
# 26          84             79             75                 87
# 27          60             65             68                 39
# 28          75             76             70                 50
# 29          91             93             87                 94
#
#     attendance_percentage                city  admission_year
# 25                     82               Kochi            2023
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   student_id             30 non-null     int64
#  1   name                   30 non-null     object
#  2   age                    30 non-null     int64
#  3   gender                 30 non-null     object
#  4   department             30 non-null     object
#  5   semester               30 non-null     int64
#  6   math_score             30 non-null     int64
#  7   science_score          30 non-null     int64
#  8   english_score          30 non-null     int64
#  9   programming_score      30 non-null     int64
#  10  attendance_percentage  30 non-null     int64
#  11  city                   30 non-null     object
#  12  admission_year         30 non-null     int64
# dtypes: int64(9), object(4)
# memory usage: 3.2+ KB

# %%
df.isnull().sum()
# Out:
# student_id               0
# name                     0
# age                      0
# gender                   0
# department               0
# semester                 0
# math_score               0
# science_score            0
# english_score            0
# programming_score        0
# attendance_percentage    0
# city                     0
# admission_year           0
# dtype: int64

# %%
df.describe()
# Out:
#         student_id        age  semester  math_score  science_score  \
# count    30.000000  30.000000      30.0   30.000000      30.000000
# mean   1015.500000  19.733333       2.0   76.066667      77.833333
# std       8.803408   0.739680       0.0   11.467896       8.554423
# min    1001.000000  19.000000       2.0   56.000000      61.000000
# 25%    1008.250000  19.000000       2.0   67.250000      71.250000
# 50%    1015.500000  20.000000       2.0   75.500000      78.000000
# 75%    1022.750000  20.000000       2.0   85.750000      83.750000
# max    1030.000000  21.000000       2.0   95.000000      93.000000
#
#        english_score  programming_score  attendance_percentage  admission_year
# count      30.000000          30.000000              30.000000            30.0
# mean       74.166667          67.600000              84.500000          2023.0
# std        10.003735          21.041175               9.379913             0.0
# ...

# %%
df.isnull().sum()
# Out:
# student_id               0
# name                     0
# age                      0
# gender                   0
# department               0
# semester                 0
# math_score               0
# science_score            0
# english_score            0
# programming_score        0
# attendance_percentage    0
# city                     0
# admission_year           0
# dtype: int64

# %%
df['math_score'].mean()
# Out:
# np.float64(76.06666666666666)

# %%
df['science_score'].max()
# Out:
# 93

# %%
df['english_score'].min()
# Out:
# 55

# %%
df[['name','math_score']]
# Out:
#               name  math_score
# 0     Aarav Sharma          85
# 1      Priya Patel          76
# 2      Rohit Verma          65
# 3      Sneha Reddy          70
# 4       Arjun Nair          92
# 5      Meera Joshi          58
# 6      Kiran Kumar          73
# 7      Divya Singh          88
# 8     Rahul Mishra          62
# 9       Ananya Das          95
# 10     Vikram Iyer          80
# 11     Pooja Gupta          67
# 12      Suresh Rao          83
# 13   Kavya Nambiar          74
# 14     Ajay Tiwari          71
# 15    Ritu Agarwal          87
# 16    Manoj Pandey          56
# 17  Swati Kulkarni          90
# 18  Deepak Chauhan          68
# 19    Nisha Kapoor          79
# 20   Harish Pillai          64
# 21     Tanvi Mehta          93
# 22    Sanjay Dubey          61
# 23   Preeti Saxena          77
# 24       Amit Bose          86
# 25      Rekha Nair          72
# 26   Gaurav Shukla          84
# 27   Sunita Pillai          60
# 28      Nitin Jain          75
# ...

# %%
df[df['math_score'] > 80]
# Out:
#     student_id            name  age  gender        department  semester  \
# 0         1001    Aarav Sharma   19    Male  Computer Science         2
# 4         1005      Arjun Nair   19    Male  Computer Science         2
# 7         1008     Divya Singh   19  Female  Computer Science         2
# 9         1010      Ananya Das   19  Female  Computer Science         2
# 12        1013      Suresh Rao   21    Male  Computer Science         2
# 15        1016    Ritu Agarwal   20  Female       Electronics         2
# 17        1018  Swati Kulkarni   19  Female  Computer Science         2
# 21        1022     Tanvi Mehta   19  Female  Computer Science         2
# 24        1025       Amit Bose   19    Male  Computer Science         2
# 26        1027   Gaurav Shukla   21    Male  Computer Science         2
# 29        1030  Akanksha Yadav   19  Female  Computer Science         2
#
#     math_score  science_score  english_score  programming_score  \
# ...

# %%
df[df['gender'] == 'Female']
# Out:
#     student_id            name  age  gender        department  semester  \
# 1         1002     Priya Patel   20  Female  Computer Science         2
# 3         1004     Sneha Reddy   20  Female        Mechanical         2
# 5         1006     Meera Joshi   20  Female       Electronics         2
# 7         1008     Divya Singh   19  Female  Computer Science         2
# 9         1010      Ananya Das   19  Female  Computer Science         2
# 11        1012     Pooja Gupta   19  Female             Civil         2
# 13        1014   Kavya Nambiar   20  Female        Mechanical         2
# 15        1016    Ritu Agarwal   20  Female       Electronics         2
# 17        1018  Swati Kulkarni   19  Female  Computer Science         2
# 19        1020    Nisha Kapoor   19  Female  Computer Science         2
# 21        1022     Tanvi Mehta   19  Female  Computer Science         2
# 23        1024   Preeti Saxena   20  Female        Mechanical         2
# ...

# %%
df.sort_values(by='math_score', ascending=False)
# Out:
#     student_id            name  age  gender        department  semester  \
# 9         1010      Ananya Das   19  Female  Computer Science         2
# 21        1022     Tanvi Mehta   19  Female  Computer Science         2
# 4         1005      Arjun Nair   19    Male  Computer Science         2
# 29        1030  Akanksha Yadav   19  Female  Computer Science         2
# 17        1018  Swati Kulkarni   19  Female  Computer Science         2
# 7         1008     Divya Singh   19  Female  Computer Science         2
# 15        1016    Ritu Agarwal   20  Female       Electronics         2
# 24        1025       Amit Bose   19    Male  Computer Science         2
# 0         1001    Aarav Sharma   19    Male  Computer Science         2
# 26        1027   Gaurav Shukla   21    Male  Computer Science         2
# 12        1013      Suresh Rao   21    Male  Computer Science         2
# 10        1011     Vikram Iyer   20    Male       Electronics         2
# ...

# %%
df['total_score']=df['math_score']+df['science_score']+df['english_score']

# %%
df.head()
# Out:
#    student_id          name  age  gender        department  semester  \
# 0        1001  Aarav Sharma   19    Male  Computer Science         2
# 1        1002   Priya Patel   20  Female  Computer Science         2
# 2        1003   Rohit Verma   19    Male       Electronics         2
# 3        1004   Sneha Reddy   20  Female        Mechanical         2
# 4        1005    Arjun Nair   19    Male  Computer Science         2
#
#    math_score  science_score  english_score  programming_score  \
# 0          85             78             72                 91
# 1          76             82             88                 79
# 2          65             74             61                 55
# 3          70             80             75                 48
# 4          92             88             81                 95
#
#    attendance_percentage       city  admission_year  total_score
# 0                     92     Mumbai            2023          235
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   student_id             30 non-null     int64
#  1   name                   30 non-null     object
#  2   age                    30 non-null     int64
#  3   gender                 30 non-null     object
#  4   department             30 non-null     object
#  5   semester               30 non-null     int64
#  6   math_score             30 non-null     int64
#  7   science_score          30 non-null     int64
#  8   english_score          30 non-null     int64
#  9   programming_score      30 non-null     int64
#  10  attendance_percentage  30 non-null     int64
#  11  city                   30 non-null     object
#  12  admission_year         30 non-null     int64
#  13  total_score            30 non-null     int64
# dtypes: int64(10), object(4)
# memory usage: 3.4+ KB

# %%
df.describe()
# Out:
#         student_id        age  semester  math_score  science_score  \
# count    30.000000  30.000000      30.0   30.000000      30.000000
# mean   1015.500000  19.733333       2.0   76.066667      77.833333
# std       8.803408   0.739680       0.0   11.467896       8.554423
# min    1001.000000  19.000000       2.0   56.000000      61.000000
# 25%    1008.250000  19.000000       2.0   67.250000      71.250000
# 50%    1015.500000  20.000000       2.0   75.500000      78.000000
# 75%    1022.750000  20.000000       2.0   85.750000      83.750000
# max    1030.000000  21.000000       2.0   95.000000      93.000000
#
#        english_score  programming_score  attendance_percentage  \
# count      30.000000          30.000000              30.000000
# mean       74.166667          67.600000              84.500000
# std        10.003735          21.041175               9.379913
# min        55.000000          38.000000              65.000000
# ...

# %%
df.shape
# Out:
# (30, 14)

# %%
df.columns
# Out:
# Index(['student_id', 'name', 'age', 'gender', 'department', 'semester',
#        'math_score', 'science_score', 'english_score', 'programming_score',
#        'attendance_percentage', 'city', 'admission_year', 'total_score'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
df['math_score'].plot()
plt.show()

# %%
dept_avg = df.groupby('department')['total_score'].mean().round(2)

# %%
print(dept_avg)
# Out:
# department
# Civil               195.20
# Computer Science    250.92
# Electronics         216.00
# Mechanical          218.00
# Name: total_score, dtype: float64
